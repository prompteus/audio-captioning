# %%
from __future__ import annotations

import pathlib
from typing import Optional, Any

import transformers
import wandb
import torch
from torch.utils.data import DataLoader
import typer
import yaml
import torchdata.datapipes as dp
import json
import time
from tqdm import tqdm

import audiocap.metrics
import audiocap.data
import audiocap.callbacks
import audiocap.models
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 17
#      14 import time
#      15 from tqdm import tqdm
# ---> 17 import audiocap.metrics
#      18 import audiocap.data
#      19 import audiocap.callbacks
#
# ModuleNotFoundError: No module named 'audiocap'

# %%
import sys
sys.executable
# !/storage/plzen1/home/ahajek/miniconda3/envs/malach23/bin/python -m pip show auidocap
# Out:
# WARNING: Ignoring invalid distribution -orch (/mnt/storage-plzen1/home/ahajek/miniconda3/envs/malach23/lib/python3.8/site-packages)
# WARNING: Package(s) not found: auidocap

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def get_whisper_model(
    config_name: str,
    config: transformers.WhisperConfig,
    load_checkpoint: pathlib.Path | None,
    use_pretrained_whisper_encoder: bool,
    use_pretrained_whisper_decoder: bool,
) -> audiocap.WhisperForAudioCaptioning:
    
    if load_checkpoint is not None:
        model = audiocap.WhisperForAudioCaptioning.from_pretrained(load_checkpoint)
        assert isinstance(model, audiocap.WhisperForAudioCaptioning)
        return model

    if use_pretrained_whisper_encoder and use_pretrained_whisper_decoder:
        model = audiocap.WhisperForAudioCaptioning.from_pretrained(config_name)
        assert isinstance(model, audiocap.WhisperForAudioCaptioning)
        return model
    
    if not use_pretrained_whisper_encoder and not use_pretrained_whisper_decoder:
        return audiocap.WhisperForAudioCaptioning(config)
    
    model_pretrained = audiocap.WhisperForAudioCaptioning.from_pretrained(config_name)
    assert isinstance(model_pretrained, audiocap.WhisperForAudioCaptioning)
    model = audiocap.WhisperForAudioCaptioning(config)

    if use_pretrained_whisper_encoder:
        model.model.encoder = model_pretrained.get_encoder()

    if use_pretrained_whisper_decoder:
        model.model.decoder = model_pretrained.get_decoder()
    
    del model_pretrained
    return model

# %%
import os
assert torch.cuda.is_available()
# !nvidia-smi
# Out:
# Wed May  3 19:01:22 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.30.02              Driver Version: 530.30.02    CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Quadro RTX 5000                 On | 00000000:C1:00.0 Off |                  Off |
# | 33%   26C    P8               13W / 230W|   6327MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    306218      C   ...miniconda3/envs/malach23/bin/python     6324MiB |
# +---------------------------------------------------------------------------------------+

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
for i in range(torch.cuda.device_count()):
    print(i, torch.cuda.get_device_properties(i))
# Out:
# 0 _CudaDeviceProperties(name='Quadro RTX 5000', major=7, minor=5, total_memory=16117MB, multi_processor_count=48)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# tensor([1, 2, 3], device='cuda:0')

# %%
ntb_dir = pathlib.Path("/storage/plzen1/home/ahajek/10semester/audio_challenge/audio-captioning/audiocap/")
load_checkpoint = ntb_dir / pathlib.Path("../checkpoints/stoic-totem-29/checkpoint-18900")
dataset_dir = ntb_dir / pathlib.Path("../data/clotho_v2.1/audiofolder/")
output_dir = ntb_dir / pathlib.Path("../inference_outputs")
generate_config = ntb_dir / pathlib.Path("../configs/generate_clotho_test.yaml")

# %%
with open(generate_config, "r") as f:
    generate_config_dict: dict = yaml.safe_load(f)

# %%
generate_args_dict = generate_config_dict["generate_args"]
architecture_config = generate_config_dict["architecture"]
architecture_name = architecture_config["name"]
use_pretrained_encoder = architecture_config["use_pretrained_whisper_encoder"]
use_pretrained_decoder = architecture_config["use_pretrained_whisper_decoder"]

only_allowed_tokens = generate_config_dict["only_allowed_tokens"]
batch_size = generate_config_dict["batch_size"]

data_config = generate_config_dict["data"]
dataset_name = data_config["dataset_name"]
task = data_config["task"]
dataset_type = data_config["dataset_type"]
data_limit = data_config["data_limit"]
run_name = load_checkpoint.parent.name  

print("run name: ", run_name)
print("dataset_path: ", dataset_dir)
# Out:
# run name:  stoic-totem-29
# dataset_path:  /storage/plzen1/home/ahajek/10semester/audio_challenge/audio-captioning/audiocap/../data/clotho_v2.1/audiofolder

# %%
config = transformers.WhisperConfig.from_pretrained(architecture_name)
tokenizer = transformers.WhisperTokenizer.from_pretrained(architecture_name, language="en", task="transcribe")
feature_extractor = transformers.WhisperFeatureExtractor.from_pretrained(architecture_name)
collator = audiocap.data.DataCollatorAudioSeq2SeqWithPadding(tokenizer, feature_extractor, keep_filename=True)
assert isinstance(config, transformers.WhisperConfig)
model = get_whisper_model(architecture_name, config, load_checkpoint, use_pretrained_encoder, use_pretrained_decoder)

tuned_params = sum(p.shape.numel() for p in model.parameters() if p.requires_grad)
total_params = sum(p.shape.numel() for p in model.parameters())
print(f"Number of trained parameters: {tuned_params}/{total_params} = {tuned_params/total_params*100:.2f}%")
# Out:
# Number of trained parameters: 1543304960/1543304960 = 100.00%

# %%
model.to(device)
# Out:
# WhisperForAudioCaptioning(
#   (model): WhisperModel(
#     (encoder): WhisperEncoder(
#       (conv1): Conv1d(80, 1280, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): Conv1d(1280, 1280, kernel_size=(3,), stride=(2,), padding=(1,))
#       (embed_positions): Embedding(1500, 1280)
#       (layers): ModuleList(
#         (0-31): 32 x WhisperEncoderLayer(
#           (self_attn): WhisperAttention(
#             (k_proj): Linear(in_features=1280, out_features=1280, bias=False)
#             (v_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (q_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (out_proj): Linear(in_features=1280, out_features=1280, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#           (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#           (final_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): WhisperDecoder(
#       (embed_tokens): Embedding(51865, 1280, padding_idx=50257)
#       (embed_positions): WhisperPositionalEmbedding(448, 1280)
#       (layers): ModuleList(
#         (0-31): 32 x WhisperDecoderLayer(
#           (self_attn): WhisperAttention(
#             (k_proj): Linear(in_features=1280, out_features=1280, bias=False)
#             (v_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (q_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (out_proj): Linear(in_features=1280, out_features=1280, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): WhisperAttention(
#             (k_proj): Linear(in_features=1280, out_features=1280, bias=False)
#             (v_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (q_proj): Linear(in_features=1280, out_features=1280, bias=True)
#             (out_proj): Linear(in_features=1280, out_features=1280, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1280, out_features=5120, bias=True)
#           (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#           (final_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (proj_out): Linear(in_features=1280, out_features=51865, bias=False)
# )

# %%
# set eval dataset
audioset_dir = None
audiocaps_dir = None
clotho_dir = None

if dataset_name == "clotho":
    ds = audiocap.data.load_clotho(dataset_dir, tokenizer, feature_extractor, None, 0, 0, 0)
elif dataset_name == "audioset":
    ds = audiocap.data.load_audioset(dataset_dir, tokenizer, feature_extractor, None, 0, 0, 0)
elif dataset_name == "audiocaps":
    ds = audiocap.data.load_audiocaps(dataset_dir, tokenizer, feature_extractor, None, 0, 0, 0)
else:
    raise ValueError(f"Unknown dataset name: {dataset_name}")

# %%
# generate captions (batched)
dataloader = DataLoader(ds[dataset_type].pipe, batch_size=batch_size, collate_fn=collator, num_workers=4)
len(dataloader)

# %%
# generate captions (batched)
dataloader = DataLoader(ds[dataset_type].pipe, batch_size=batch_size, collate_fn=collator, num_workers=4)
all_predictions = []
for i, batch in enumerate(dataloader):
    if data_limit and i >= data_limit/batch_size:
        break
    filenames = batch.pop("file_name")
    prediction_ids = model.generate(batch["input_features"].to(device), 
                                    forced_ac_decoder_ids=batch["forced_ac_decoder_ids"].to(device), 
                                    **generate_args_dict)
    predictions = tokenizer.batch_decode(prediction_ids, skip_special_tokens=False)
    predictions_dict = [{"file_name": fn, "caption": p} for fn, p in zip(filenames, predictions)]
    all_predictions.extend([{"file_name": fn, "caption": p} for fn, p in zip(filenames, predictions)])
    [print(p) for p in predictions_dict]
# Out:
# {'file_name': '20070720.rbd.chicharras.02.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and vibrating, and people are talking in the background<|endoftext|>'}
# {'file_name': 'Appartment_Ambient_AC_TV_Fans.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A boat motor is running and fades<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'kikkers.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows and an animal breathes<|endoftext|><|endoftext|>'}
# {'file_name': 'Rushing_water+wind-Rec_Samsung_HMX-F80_Camcorder.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is running and gurgling<|endoftext|>'}
# {'file_name': 'Outdoors, Cars pass by.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and accelerating<|endoftext|>'}
# {'file_name': 'lakefountain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water flows and a frog croaks<|endoftext|>'}
# {'file_name': 'Scops owl&#39;s call in night silence.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bird tweeting<|endoftext|>'}
# {'file_name': 'Evening suburban ambience.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves far away<|endoftext|><|endoftext|>'}
# {'file_name': 'Machine 2 multi Stage.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat engine running steadily<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Chopping Celery.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Scraping and tapping noises followed by a sawing sound<|endoftext|>'}
# {'file_name': 'Metro - Greece.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves nearby followed by a person talking<|endoftext|>'}
# {'file_name': 'Metallic Lingo.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell is jingled<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'DH14_CrowTram2b.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves and a dog barks<|endoftext|>'}
# {'file_name': 'steam train 05.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and banging with distant speech<|endoftext|><|endoftext|>'}
# {'file_name': 'Canada Geese Squawk on a Pond with a Fountain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirp and ducks quack<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'growing pipe(s)-2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A muffled vehicle engine accelerating alongside metal lightly squeaking as wind blows into a microphone<|endoftext|>'}
# {'file_name': 'WaterBottle.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling plastic followed by a person breathing<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'New Inn.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: People are talking and clanging pots and pans<|endoftext|>'}
# {'file_name': 'Cracking and frying egg.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A metal object clangs and food fries<|endoftext|>'}
# {'file_name': 'Super Market.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves slowly<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Diesel Truck Idling Front.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorcycle engine idling<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Household - Atmos - Wind Through Window.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle is speeding along the road<|endoftext|>'}
# {'file_name': 'Nature sounds close to garden.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirp in the background, followed by a tapping sound<|endoftext|>'}
# {'file_name': 'Footsteps outside - Including ambience.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A horse galloping and birds chirping<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Grand Union Canal Kensal Green.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds are chirping and a single owl squawks<|endoftext|>'}
# {'file_name': 'in_cafe_4.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: People are talking and metal is clanging<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Village road.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dog barks while a vehicle passes by<|endoftext|>'}
# {'file_name': 'sand falling on paper.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and hissing<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Heavy Wind.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows nearby quietly<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Spanish pinball machine in bar.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and distant murmuring<|endoftext|>'}
# {'file_name': 'Backhoe.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle engine accelerating followed by metal clacking<|endoftext|>'}
# {'file_name': 'Owls.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A small animal squeaks<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Toilet Flushaf.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A toilet is flushed<|endoftext|>'}
# {'file_name': 'Freezing Rain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls and birds chirp<|endoftext|><|endoftext|>'}
# {'file_name': 'Bees Collingwood.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds are chirping and insects are buzzing<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'junction_night_traffic.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle engine revving several times as a woman talks in the background<|endoftext|>'}
# {'file_name': 'small dog leaves.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and crinkling paper<|endoftext|>'}
# {'file_name': 'Forbidden Purr02.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person snores quietly<|endoftext|><|endoftext|>'}
# {'file_name': 'Train passing by and horning in Romania (Bacau). Close recording.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A train horn blows<|endoftext|><|endoftext|>'}
# {'file_name': 'French fries in the making.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|>'}
# {'file_name': 'bolivar_stan_playing.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water flows and splashes as children speak<|endoftext|>'}
# {'file_name': 'Weight machine, gas resistance.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A drill is being used<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': '20070402.crowd.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking as birds chirp in the background<|endoftext|>'}
# {'file_name': '15_Rain_Ocean_HeavierLighter_44_16.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls and something is hit very hard<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Metal_Gate_squeak_mono.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and squealing of wood<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Kowloon Park.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping followed by a woman talking<|endoftext|>'}
# {'file_name': 'SpringWoodsWarblersPlusDistantGeeseMay52013.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and singing<|endoftext|>'}
# {'file_name': 'Glass moving 2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person crinkles paper nearby<|endoftext|>'}
# {'file_name': '20121014_boat_tour_01.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A helicopter flies overhead as people talk<|endoftext|>'}
# {'file_name': 'metal workshop quiet.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person sprays with a sprayer<|endoftext|>'}
# {'file_name': 'nnus_forklift_driveby.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle is speeding by<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'el sonido del arbol y la tierra yerlin .wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaks while wind blows and children speak far away<|endoftext|>'}
# {'file_name': 'metal-bell-percussion.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell rings several times<|endoftext|>'}
# {'file_name': 'fs_brokenMixer302-2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A loud explosion followed by silence<|endoftext|><|endoftext|>'}
# {'file_name': 'Train Pass Koln.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person speaks over a loudspeaker<|endoftext|>'}
# {'file_name': '080809_05_FontanaKoblerov.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls heavily<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'amradiochanging.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaks while a machine runs<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'dissolvingEffervescentTablet.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clinking and scraping followed by a glass clink<|endoftext|>'}
# {'file_name': 'Gazpoile_long.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle engine idling<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Santas workshop.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking as a person is blowing a horn while a vehicle engine revs up and down<|endoftext|>'}
# {'file_name': 'RoomTone.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A machine hums and vibrates<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'woodsbirds.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|>'}
# {'file_name': 'Cruiseship - outside, night.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat is speeding along<|endoftext|><|endoftext|>'}
# {'file_name': '07 ambient bell.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell rings and birds chirp<|endoftext|>'}
# {'file_name': 'Footsteps on snow.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person is scraping something<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'somethingatthedoor.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A tapping sound followed by a sliding sound<|endoftext|>'}
# {'file_name': 'gym machine 2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat engine hums along slowly<|endoftext|>'}
# {'file_name': 'Teig ausrollen.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clicking and banging<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Ocean Waves 1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A boat motor is running and accelerating<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'microondas.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and slows, and metal clicking occurs<|endoftext|>'}
# {'file_name': 'DIDGERIDOO 05.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A frog is croaking<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'dripping taps.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person coughs while liquid flows<|endoftext|>'}
# {'file_name': 'Balloon Game at Arlington Heights Carnival.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: People are talking and something is being hit hard<|endoftext|>'}
# {'file_name': 'crunchy_steps.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and crumpling paper<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'ELEVATOR CABIN (DOORS OPEN CLOSE).wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A door slams shut<|endoftext|><|endoftext|>'}
# {'file_name': 'Cityscape Compounded 01.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat engine running idle<|endoftext|>'}
# {'file_name': 'food_prep_1_cw.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and scraping food<|endoftext|>'}
# {'file_name': 'shopping-cart-rattle.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and hissing<|endoftext|>'}
# {'file_name': 'Outside02.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows and waves crash<|endoftext|><|endoftext|>'}
# {'file_name': 'Tires car without an engine.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls and wind blows<|endoftext|>'}
# {'file_name': 'Riverdream Water HGain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A large motor vehicle engine is running and vibrating<|endoftext|>'}
# {'file_name': 'growling thunder.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Thunder rolls in the distance<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'texture paper.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|>'}
# {'file_name': 'trumpet.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A musical instrument with people speaking<|endoftext|><|endoftext|>'}
# {'file_name': '043015 Splashing water in bathtub.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water splashes and gurgles<|endoftext|>'}
# {'file_name': 'descending noise sweep.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A high pitched engine accelerating<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Ahr river.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is running and splashing<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Door.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person breathes, followed by a gunshot<|endoftext|>'}
# {'file_name': 'fdv_orage.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Thunder rolls in the distance as rain falls<|endoftext|>'}
# {'file_name': 'Living Minute - Winter Thaw.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls and wind blows<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'saturday_ambiance.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle horn honking followed by a man talking as a crowd of people talk in the background<|endoftext|>'}
# {'file_name': 'stereo ambient indoors living room heavy traffic outside.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves nearby<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'River far 1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirp and water splashes<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Japan_Tokyo_Shinjuku_Street_Promoter_Yelling_City.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaking as a motorboat engine hums and water splashes<|endoftext|>'}
# {'file_name': 'Collingwood bees, bumble bees.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds are chirping and bees are buzzing<|endoftext|><|endoftext|>'}
# {'file_name': 'Pencil 1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and scraping followed by a brief tone<|endoftext|>'}
# {'file_name': 'Money in the bag.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaking and a horse galloping<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': '20080505_1309unlock_doors.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirp in the distance, followed by a door opening nearby<|endoftext|>'}
# {'file_name': 'Cash Machine, Indoors, Full Transaction.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Beeping followed by a motor running and more beeping<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'freight train close by wooded park.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A train is passing by and honking its horn<|endoftext|>'}
# {'file_name': 'Blackbird 252.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'water_boil_pour_stir-96.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A glass of something metal is scraped<|endoftext|>'}
# {'file_name': '20160506_sharpening.02.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Scraping and filing of wood<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Erik Final.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A ping followed by rustling and a motorboat engine running<|endoftext|>'}
# {'file_name': 'Galactic signal 3.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A high pitched beep is continuous as something else goes off<|endoftext|>'}
# {'file_name': 'junk_box001.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging of metal and wood<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': '20090712.engine.01.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and accelerating, and an adult male speaks<|endoftext|>'}
# {'file_name': '20070918.galloping.horse.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A horse galloping on a hard surface as a small animal bleats<|endoftext|>'}
# {'file_name': '20090407.cricket.real.close.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A small motor is running and vibrating<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'toy rattle 2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A small motor is running, metal is clanging, and metal is squeaking<|endoftext|>'}
# {'file_name': 'STE-002-dishes_lisbon_restaurant.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking as metal clanks while birds chirp in the background<|endoftext|>'}
# {'file_name': '20160820_saluzzo.arcade.04.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': '20100320.fountain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is dripping<|endoftext|><|endoftext|>'}
# {'file_name': 'Tortured Apple 03.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Someone crinkles plastic<|endoftext|>'}
# {'file_name': 'Heavy rain and thunder in Oklahoma.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls and thunder roars<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'People talking while waiting the bus.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaking while a crowd of people talk in the background<|endoftext|>'}
# {'file_name': 'squirrel upset.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and squawking<|endoftext|>'}
# {'file_name': 'Slow Windchimes.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell is chiming<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': '20100422.waterfall.birds.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|><|endoftext|>'}
# {'file_name': 'Fountain Trompenburg 090928.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is sloshing and a child is yelling<|endoftext|>'}
# {'file_name': 'Lluvia 1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls and thunder roars<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'street_ambience_day.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle engine revving followed by a crowd of people talking and a horse galloping<|endoftext|>'}
# {'file_name': 'E-brake.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person is crinkling paper<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'fallingbeans.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person breathes, some crinkling and scraping<|endoftext|>'}
# {'file_name': 'Juicer Shredding and Shutting Down.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A small motor is running and buzzing, and metal clicking occurs<|endoftext|>'}
# {'file_name': 'Hail 1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clicking and rattling<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Remix of 101674__Robinhood76__01906_aluminium_foil_&#39;space-alien radio-static remix&#39;.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person sprays with a compressor<|endoftext|>'}
# {'file_name': 'footsteps_2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person hammers wood<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'creaky.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person walks on a hard surface as a bird calls out<|endoftext|>'}
# {'file_name': 'bird-chatter4.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Calm down-town morning 02 150722_0706.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting followed by a cough<|endoftext|>'}
# {'file_name': 'rhythm of the falling drops.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A woman and man speak while a horse gallops<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'miniature goats and sheep.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Goats bleating with people talking in the background<|endoftext|>'}
# {'file_name': 'Thunder - Guangzhou - China - Quiet.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Thunder rolls in the distance<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Motor - Water Pump, Small Fountain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorcycle engine idling<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'sparrows.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and squawking<|endoftext|>'}
# {'file_name': 'Cars crossing in Rain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Waves move closer and closer<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'traffic w scott.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves nearby while people talk far away<|endoftext|>'}
# {'file_name': 'Knife Hitting Wine Glass.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell rings several times<|endoftext|><|endoftext|>'}
# {'file_name': 'Howler monkey and other monkey or bird.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and squawking<|endoftext|>'}
# {'file_name': 'HOSTEL WORKS 1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A guitar plays a song<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'rain.gutter.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|>'}
# {'file_name': 'recycling center 1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and vibrating, and people are talking in the background<|endoftext|>'}
# {'file_name': 'Waterfalls_00216.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Red Beach at night - RJ.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows and waves crash<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'April_2004_garden_birds01.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|>'}
# {'file_name': 'flock of geese flying over2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A group of ducks quacking<|endoftext|>'}
# {'file_name': 'sw_SolitaryCricket_NR_01.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bird is chirping<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Spring Lambs at Middle Hulme Farm Near Meerbrook.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A small motor vehicle engine is running and birds are chirping<|endoftext|>'}
# {'file_name': '02668 stripwood noises.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanking and banging<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'nxSample002.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A sprayer is hissing<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'night ambient crickets bugs white noise occasional cough.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A machine works while a man coughs<|endoftext|>'}
# {'file_name': 'Brushing teeth.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person is scrubbing wood followed by a toilet flushing<|endoftext|>'}
# {'file_name': 'dogs_berlin.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dog barks and a dog is barking<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'THE_RATT21_1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Waves are crashing ashore as the wind blows by<|endoftext|><|endoftext|>'}
# {'file_name': 'Walking shingle beach.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person sprays nearby as birds chirp in the distance<|endoftext|>'}
# {'file_name': 'Siren Milan.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Ambulance siren is going off<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'small crowd outdoors.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking as a child cries while wind blows into a microphone<|endoftext|>'}
# {'file_name': 'Cooking rice.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows strongly nearby as a horse gallops by<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'bunker drip resonance 1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and fades, and metal tinkling occurs<|endoftext|>'}
# {'file_name': 'Radio Fuzz for Old Radio Broadcast FF233.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls and windshield wipers move<|endoftext|>'}
# {'file_name': 'hostpital-automatic-bed.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanking and squeaking<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'keurig-coffe-maker.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat engine accelerates<|endoftext|>'}
# {'file_name': 'Playing organ with an open window.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Music plays while rain falls<|endoftext|><|endoftext|>'}
# {'file_name': 'Field-Recording.LawnMower.4.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and accelerating<|endoftext|>'}
# {'file_name': 'scissors_cut_paper.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clicking and crinkling paper<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'construction_rubber_mallet_01.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A wood object is hit very hard<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Garbage Truck.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A truck engine is running and a person shuffles their feet<|endoftext|>'}
# {'file_name': '27 hn_birdspecking.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A horse galloping<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Footsteps_Leaves_Walking.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and crumpling paper<|endoftext|>'}
# {'file_name': 'wood1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and banging of wood<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Fountain .wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is splashing and gurgling<|endoftext|>'}
# {'file_name': 'Steam 20.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A clock ticking<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Walking on crunchy snow.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rustling and scraping of paper<|endoftext|>'}
# {'file_name': 'OrchestraTuning1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A musical instrument plays with a high-pitched sound, followed by applause<|endoftext|>'}
# {'file_name': 'bus pass.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A horse galloping by on a windy day<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Crowd Atmos.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking and screaming<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Car vs. Freight Train.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A train horn blows, train wheels squeal, a train approaches, and hissing occurs<|endoftext|>'}
# {'file_name': 'Ford Mustang Engine (1985).wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorcycle engine starting up then running idle<|endoftext|>'}
# {'file_name': 'Toilet Shuffling.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A toilet is flushed<|endoftext|><|endoftext|>'}
# {'file_name': 'little creek in the woods.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is running and gurgling<|endoftext|>'}
# {'file_name': 'Large Warehouse_Factory Ambience.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A boat motor is running and fades<|endoftext|><|endoftext|>'}
# {'file_name': '20100801.wharf.silence.night.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bird chirps and a man speaks<|endoftext|><|endoftext|>'}
# {'file_name': 'RadioFan.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaking with music in the background<|endoftext|>'}
# {'file_name': '20090105.slicing.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person is crinkling paper<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Street Market 2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaking and a horse galloping<|endoftext|>'}
# {'file_name': 'FlushToilet.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A toilet is flushed<|endoftext|><|endoftext|>'}
# {'file_name': '20080504.horse.drawn.00.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and a horse galloping<|endoftext|>'}
# {'file_name': 'MISC_Int_Cat_Purring_002.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dog is purring<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'industrial_crash02.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A loud explosion with a muffled sound<|endoftext|>'}
# {'file_name': 'a boy and 2 pigs.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: People are talking and pig oinking<|endoftext|>'}
# {'file_name': 'Pulley Sounds.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person is crinkling paper<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'OrchardBirds.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|>'}
# {'file_name': 'Street_Car.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves and someone speaks<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Sea Atmosphere.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Waves are crashing ashore<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Train passing by in a rail station in Brussels (Schaerbeek).wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A horn honking followed by a vehicle engine revving<|endoftext|>'}
# {'file_name': 'smallgrocery.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell rings and people are talking<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Unseathing &amp; Wobble.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaking followed by several short brief brief electronic beeps<|endoftext|>'}
# {'file_name': 'Footsteps Gravel Trainers Running 96Hz 24 Bit.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person walking on a hard surface<|endoftext|><|endoftext|>'}
# {'file_name': 'MorningOwlsAug29th2015.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and cooing<|endoftext|>'}
# {'file_name': 'POLLA AIGUA 0.16.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dog whimpers<|endoftext|>'}
# {'file_name': 'AMB_earlymorning_palmovka.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves getting closer<|endoftext|>'}
# {'file_name': 'SuburbRain_Indoor.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves closer and closer<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Mass MoCA Bathroom Door.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell rings and a horse neighs<|endoftext|>'}
# {'file_name': 'Railroad Crossing Japan.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A train is chugging along the tracks while a train whistle goes off<|endoftext|>'}
# {'file_name': 'paper falling and crunching_1-2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and crumpling paper<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Hang Man&#39;s Rope.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and crumpling paper<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'VA State Fair # 10 (Quieter Crowd Noise).wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaking over a loudspeaker as a crowd of people talk and laugh<|endoftext|>'}
# {'file_name': 'Hanoi streets.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and accelerating, people are talking, and a child speaks in the background<|endoftext|>'}
# {'file_name': 'Sink Drain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging of metal and wood<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': '20091217.17.fountain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is running and splashing<|endoftext|>'}
# {'file_name': '20140809_cruzul.river.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is running and splashing<|endoftext|>'}
# {'file_name': 'Grovers Love 100.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Music is being played on a hard surface<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Footsteps_Sneakers_Wet Sidewalk-01.R.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person walking on grass and a horse galloping<|endoftext|>'}
# {'file_name': 'west ham bubbles.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: singing, musical instrument, choir, male singing<|endoftext|><|endoftext|>'}
# {'file_name': 'stclaude.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Music plays nearby as a person sprays a surface<|endoftext|>'}
# {'file_name': 'Rynek Warszaski.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A baby cries while birds tweet<|endoftext|><|endoftext|>'}
# {'file_name': 'bird_in_rain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|>'}
# {'file_name': 'clinking_tiles_01.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and spraying with distant speech<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'bandung-taxiradio-1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man and woman are speaking over a loudspeaker, and a motor vehicle engine is running and accelerating<|endoftext|>'}
# {'file_name': '20061121.pine.forest.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|>'}
# {'file_name': 'Sonido de fondo y trafico.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves closer and closer<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Wood Floor.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Someone moves wood objects around<|endoftext|>'}
# {'file_name': 'living room tone  ambient distant noises neighbours.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves slowly<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'village bar.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: People are communicating and a horse neighs<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'porto_morning_tropical_birds_market_20.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirp and squawk as people speak<|endoftext|>'}
# {'file_name': 'invexdpo.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A muffled vehicle engine accelerating<|endoftext|><|endoftext|><|endoftext|>'}
# ...
# {'file_name': 'FrogsBlackHill.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A frog croaking<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'BottleDrinking02.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Scraping and rustling of paper followed by a clink<|endoftext|>'}
# {'file_name': 'arriving_montpellier_by_train.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaks followed by a woman speaking and a man speaking<|endoftext|>'}
# {'file_name': 'Rain Loop with Low-Cut Filter.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Train coming in.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A train moves closer and closer on tracks<|endoftext|>'}
# {'file_name': 'Nord_Odal_Nyhus_04_juni_2011_quiet_forest_birds_insects_leaf_rustle_02.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and singing<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'alpine bird under the rain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and singing<|endoftext|>'}
# {'file_name': 'small_water_fall_in_the_woods_2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is running and splashing<|endoftext|>'}
# {'file_name': 'Sunny Afternoon Suburb Ambiance .wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves getting closer<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Thunder burst with rain.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls and thunder roars<|endoftext|>'}
# {'file_name': 'Pouring Into Glass.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is being sprayed<|endoftext|>'}
# {'file_name': 'Car_Suspension_Creak.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bee buzzes around<|endoftext|>'}
# {'file_name': 'Thunder3.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows strongly nearby<|endoftext|><|endoftext|>'}
# {'file_name': 'interference from wireless mouse on am radio.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorcycle engine idling<|endoftext|>'}
# {'file_name': 'mall  loud voices.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking and cheering<|endoftext|>'}
# {'file_name': 'Plane Over Traffic.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves getting closer<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'fireworks scare birds 150828_0743.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A horse galloping on a hard surface as birds chirp in the background<|endoftext|>'}
# {'file_name': 'singing bell hit 2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell is being rung<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Grinder.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A small motor is running and metal whirring is present<|endoftext|>'}
# {'file_name': 'glenhaven_stream.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Wobbling of paper.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clattering and scraping occur simultaneously<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'San Francisco Traffic at Powell And O&#39;Farrell.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and accelerating<|endoftext|>'}
# {'file_name': 'tornado day 4.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and accelerating, and birds are chirping<|endoftext|>'}
# {'file_name': '02-Bakken_Rollercoaster.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves and several people scream<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Queen Street Mill, loom running then stops.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A loud clicking and tapping sound<|endoftext|><|endoftext|>'}
# {'file_name': 'viento.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person snores nearby as a person laughs<|endoftext|>'}
# {'file_name': 'Train and dog.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dog barks while a clock is ticking<|endoftext|>'}
# {'file_name': 'Metal spoon on china plate.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clinking and scraping<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Bear Last Audio.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person sneezes<|endoftext|>'}
# {'file_name': 'TRAN_Plane_PropSpin_01.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A helicopter flies nearby<|endoftext|>'}
# {'file_name': 'BlackCappedChickadee.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bird chirps<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Spring Birds Raw (New Jersey).wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and singing<|endoftext|>'}
# {'file_name': 'Broom_Bear_Street_Sweeper_Roadwork.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A large motor vehicle engine is running and fades somewhat<|endoftext|>'}
# {'file_name': 'london-st-james-park-feeding-the-birds.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Several ducks quacking<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'water puddle.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person is scrubbing something as they drink<|endoftext|>'}
# {'file_name': 'Light Wind.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows and rain falls<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'WATER DRIPPING ECHO.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is being splashed<|endoftext|><|endoftext|>'}
# {'file_name': 'a flag is waving at the pole.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A metal object is jingled<|endoftext|>'}
# {'file_name': 'mall_1_escalator_0725_113354.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bus idling and people talking far away<|endoftext|>'}
# {'file_name': '20080320.farm.ambiance.2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'crickets in the woods.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A machine is spraying liquid<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'bologna_street1.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A large motor vehicle engine is running and accelerating, and people are talking and laughing<|endoftext|>'}
# {'file_name': '20140223 - Bangkok city sounds.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: People are communicating while a vehicle engine is running<|endoftext|>'}
# {'file_name': 'Kitchen fan.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat engine hums<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'can.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clinking and chinkling of a glass<|endoftext|>'}
# {'file_name': 'weird rapidbeat.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A muffled sound is heard<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Stadium Wind.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle is driving with a siren noise<|endoftext|>'}
# {'file_name': 'Blowing on Microphone.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person snores quietly<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'driveaway.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and accelerating<|endoftext|><|endoftext|>'}
# {'file_name': 'Deutz-Tractor-Engine-1972.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is idling and vibrating<|endoftext|>'}
# {'file_name': 'startupjetengine.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A loud engine running consistently<|endoftext|>'}
# {'file_name': 'Room Tone Inside a Car.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A stream of water flows<|endoftext|>'}
# {'file_name': '01 A pug struggles to breathe 1_14_2008.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person sniffling and sniffling followed by a person snoring<|endoftext|>'}
# {'file_name': 'More waves at Collingwood.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water splashes and gurgles<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Tractor1 FF654.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle engine idling<|endoftext|><|endoftext|>'}
# {'file_name': 'opening attic.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and banging of wood<|endoftext|>'}
# {'file_name': 'Oystercatchers and Chic.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bird squeals as ocean waves crash and people talk in the background<|endoftext|>'}
# {'file_name': 'Nord_Odal_Nyhus_04_juni_2011_quiet_forest_birds_insects_leaf_rustle_04.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and insects buzzing<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Glass Bottles rattle and chink.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A glass of something metal is clanging<|endoftext|>'}
# {'file_name': 'Car Driving.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat is speeding along<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'adw018raw.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A clock is chiming<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Fergus Whining.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dog whimpers and howls<|endoftext|>'}
# {'file_name': 'Armoury Site.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorcycle speeds by<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'buzzing stinging.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat engine hums along and a bee buzzes<|endoftext|>'}
# {'file_name': 'SeaShell_02.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person breathes heavily followed by crinkling paper<|endoftext|>'}
# {'file_name': 'Air raid siren_rising.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle siren sounds as birds chirp<|endoftext|><|endoftext|>'}
# {'file_name': 'Ronda - Fountain near the Town Hall (general) - Fuente cerca del Ayuntamiento (general).wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|>'}
# {'file_name': 'Street sounds cars.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows and a motorboat approaches<|endoftext|>'}
# {'file_name': 'traffic and footsteps.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves getting closer<|endoftext|>'}
# {'file_name': 'Roosters and dogs wake up in the small village of La Preciosita.  A morning in Mexican countryside.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A rooster crowing<|endoftext|>'}
# {'file_name': 'Santa Motor.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A small motor is running and buzzing, and rhythmic tapping is present<|endoftext|>'}
# {'file_name': 'freight_on_bridge.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and banging of an engine<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Donner2.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Thunder rolls in the distance<|endoftext|>'}
# {'file_name': 'DoorSqueak.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dog is whimpering<|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'walk up carpet steps.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A horse galloping<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}
# {'file_name': 'Ambience - St Kilda Beach - waves lapping rocks, people nearby, seagulls.wav', 'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat engine hums along as water splashes<|endoftext|>'}

# %%
all_predictions
# Out:
# [{'file_name': 'People Working - Inner Courtyard - Church Bells.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Music plays nearby as a person sprays on a surface<|endoftext|>'},
#  {'file_name': 'Air door sound.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows and a vehicle approaches<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'Rainy weather.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A large motor vehicle engine is running and vibrating<|endoftext|>'},
#  {'file_name': 'Trsat_Afternoon_--.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bus engine hums<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'fireworks.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Several explosions and fireworks with some whistling and humming<|endoftext|>'},
#  {'file_name': 'Cup_spoon_hotwater.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging of glass and liquid<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'TREADMILL_GYM-AMB.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A machine is spraying a surface<|endoftext|><|endoftext|>'},
#  {'file_name': 'Rocks Falling No-Reverb Edition 16 Bit.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|>'},
#  {'file_name': 'Outside Ambience.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat is speeding along<|endoftext|><|endoftext|>'},
#  {'file_name': 'Metal_Workshop_4.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A machine works while some liquid flows<|endoftext|>'},
#  {'file_name': '20140530.country.house.night.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A loud beeping sound with people talking<|endoftext|>'},
#  {'file_name': 'Cars passing by.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Traffic passes by<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'India Kerala Beach (Waves, Voices, Wind Noise).wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Waves crashing and people talking<|endoftext|>'},
#  {'file_name': 'Plane Flies Overhead In Forest.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell is ringing<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'Knife 1.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person is scraping a wooden object<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'countryside at night with a dog barking afar.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dog barks and a child shouts far away<|endoftext|>'},
#  {'file_name': 'Blurbing about.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows and water splashes<|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'Boiling a kettle of water_110218_02_SF.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and vibrating<|endoftext|>'},
#  {'file_name': 'stereo ambient indoors small room 2 PUMPED UP 30 DB.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves slowly<|endoftext|><|endoftext|>'},
#  {'file_name': 'Vacuum cleaner.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A drill is being used<|endoftext|>'},
#  {'file_name': 'Half bathroom with more toilet noise.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is running and gurgling<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'SP_evangelist.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man yells while others talk in the background<|endoftext|>'},
#  {'file_name': 'Hotel room ventilator.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A boat engine hums<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'kamakura_rest_stop.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man talking with a woman and children talking in the background<|endoftext|>'},
#  {'file_name': 'vacuum_cleaner_CO.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A drill is being used<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'bird sounds.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|>'},
#  {'file_name': 'driving with sirens.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A police siren is going off and cars are passing by<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'crikvenica_croatia__walking_in_the_city.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and accelerating, and people are talking in the background<|endoftext|>'},
#  {'file_name': 'Fire Escape AMB.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'footsteps on carpet.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A scraping sound with a person talking far away<|endoftext|>'},
#  {'file_name': 'Hyeres street sounds child.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking as a kid cries while a vehicle engine runs idle<|endoftext|>'},
#  {'file_name': 'rolling paint.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging noises followed by a dog barking<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'mbring violin feedback.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell rings and a synthesized object is played<|endoftext|>'},
#  {'file_name': 'parking2.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle engine idling and people talking<|endoftext|>'},
#  {'file_name': 'Paper Cup Hollow Slide Scissor Snips.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person breathes heavily and something is repeatedly and forcefully filed<|endoftext|>'},
#  {'file_name': '109473__jovica__layers-020-n-dimensional-space-62_2.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A muffled vehicle engine accelerating as wind blows into a microphone<|endoftext|><|endoftext|>'},
#  {'file_name': 'Ambience Coffee Shop 4 .wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'Maritiem Museum Mainport 07 090511.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A woman speaking in the background as a group of people talk in the distance<|endoftext|>'},
#  {'file_name': 'RED LINE.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A machine works while a woman talks far away<|endoftext|>'},
#  {'file_name': '18 Little Group.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A humming and music<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': '20100327.seafront.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves and a man talks<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'TRAIN_MSSG.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaks over a loudspeaker as a small motor revs up<|endoftext|>'},
#  {'file_name': 'ambient__DEEP.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves slowly<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'Food Sizzling.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls and something is fried<|endoftext|>'},
#  {'file_name': 'Shaking pills in plastic container.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and crumpling paper<|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'Urban Ambience(birds, wind, leaves, cars)_1-2.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle engine is running and birds are chirping<|endoftext|>'},
#  {'file_name': 'Stream_00198.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water rushes down a stream<|endoftext|>'},
#  {'file_name': 'metal on metal.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and scraping of wood<|endoftext|><|endoftext|>'},
#  {'file_name': 'macbook fan noise.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A small motor is running and accelerates<|endoftext|>'},
#  {'file_name': 'car_1.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle is speeding by<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'Horses.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A helicopter flies overhead<|endoftext|><|endoftext|>'},
#  {'file_name': 'Popcorn pop.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and splashing water<|endoftext|>'},
#  {'file_name': 'Ocean 1.0 9-11-16.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows strongly nearby<|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'am statics 1040 to 1220.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat engine running steadily<|endoftext|>'},
#  {'file_name': 'Cuckoo bird.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves while people talk<|endoftext|>'},
#  {'file_name': 'Crushing that Thin Layer of Ice.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and crumpling paper<|endoftext|>'},
#  {'file_name': 'Bird-one Mockingbird with many songs.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|><|endoftext|>'},
#  {'file_name': 'Cockney weather news.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person talking with a squeaky sound<|endoftext|>'},
#  {'file_name': 'rtty 75 bd testslip the quick brown fox and 1 row ry.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dial tone is going off<|endoftext|>'},
#  {'file_name': 'rain-fragment-eq.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|>'},
#  {'file_name': 'clinking_tiles_02.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and rustling<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'wildernessambience.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A boat motor is running and fades, and birds are chirping<|endoftext|>'},
#  {'file_name': 'Ambience windy street with trees and birds.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves nearby<|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'a gentle breeze, wind 5.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bee buzzes loudly nearby<|endoftext|>'},
#  {'file_name': '1 person walking on pavement outside.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A horse galloping and a person singing far away<|endoftext|>'},
#  {'file_name': 'FaucetMetalSink90.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is running and gurgling<|endoftext|><|endoftext|><|endoftext|>'},
#  {'file_name': 'ink jet printer.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clicking and rustling with some light humming<|endoftext|>'},
#  {'file_name': 'Whitchurch Silk Mill waterwheel 1.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A steam engine is chugging along<|endoftext|><|endoftext|>'},
#  {'file_name': 'on a wooden ship at sea 02.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water splashes and birds chirp<|endoftext|>'},
#  {'file_name': 'Machetes buffed.wav',
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell is clanging<|endoftext|><|endoftext|><|endoftext|><|endoftext|>'}]

# %%
# generate captions (filename)
all_predictions = []
for i, batch in tqdm(enumerate(DataLoader(ds[dataset_type].pipe, batch_size=1))):
    if data_limit and i >= data_limit:
        break

    batch_features = [{"input_features": x["input_features"]} for x in [batch]]
    batch_forced_ac_decoder_ids = [x["forced_ac_decoder_ids"] for x in [batch]]

    col_batch = feature_extractor.pad(batch_features, return_tensors="pt")
    col_batch["forced_ac_decoder_ids"] = torch.tensor(batch_forced_ac_decoder_ids)

    prediction_ids = model.generate(col_batch["input_features"][0].to(device), 
                                    forced_ac_decoder_ids=col_batch["forced_ac_decoder_ids"].to(device), 
                                    **generate_args_dict)
    prediction = tokenizer.batch_decode(prediction_ids, skip_special_tokens=False)[0]
    all_predictions.append({"file_name": batch["file_name"], "caption": prediction})
    print(batch["file_name"], prediction)
# Out:
# ['People Working - Inner Courtyard - Church Bells.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Music plays nearby as a person sprays on a surface<|endoftext|>
# ['Rainy weather.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A large motor vehicle engine is running and vibrating<|endoftext|>
# ['fireworks.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Several explosions and fireworks with some whistling and humming<|endoftext|>
# ['TREADMILL_GYM-AMB.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A machine is spraying a surface<|endoftext|>
# ['Air door sound.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows and a vehicle approaches<|endoftext|>
# ['Trsat_Afternoon_--.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bus engine hums<|endoftext|>
# ['Cup_spoon_hotwater.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging of glass and liquid<|endoftext|>
# ['Rocks Falling No-Reverb Edition 16 Bit.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|>
# ['Outside Ambience.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat is speeding along<|endoftext|>
# ['20140530.country.house.night.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A loud beeping sound with people talking<|endoftext|>
# ['India Kerala Beach (Waves, Voices, Wind Noise).wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Waves crashing and people talking<|endoftext|>
# ['Knife 1.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person is scraping a wooden object<|endoftext|>
# ['Metal_Workshop_4.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A machine works while some liquid flows<|endoftext|>
# ['Cars passing by.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Traffic passes by<|endoftext|>
# ['Plane Flies Overhead In Forest.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell is ringing<|endoftext|>
# ['countryside at night with a dog barking afar.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dog barks and a child shouts far away<|endoftext|>
# ['Blurbing about.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows and water splashes<|endoftext|>
# ['stereo ambient indoors small room 2 PUMPED UP 30 DB.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves slowly<|endoftext|>
# ['Half bathroom with more toilet noise.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is running and gurgling<|endoftext|>
# ['Hotel room ventilator.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A boat engine hums<|endoftext|>
# ['Boiling a kettle of water_110218_02_SF.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and vibrating<|endoftext|>
# ['Vacuum cleaner.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A drill is being used<|endoftext|>
# ['SP_evangelist.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man yells while others talk in the background<|endoftext|>
# ['kamakura_rest_stop.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man talking with a woman and children talking in the background<|endoftext|>
# ['vacuum_cleaner_CO.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A drill is being used<|endoftext|>
# ['driving with sirens.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A police siren is going off and cars are passing by<|endoftext|>
# ['Fire Escape AMB.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|>
# ['Hyeres street sounds child.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking as a kid cries while a vehicle engine runs idle<|endoftext|>
# ['bird sounds.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|>
# ['crikvenica_croatia__walking_in_the_city.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and accelerating, and people are talking in the background<|endoftext|>
# ['footsteps on carpet.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A scraping sound with a person talking far away<|endoftext|>
# ['rolling paint.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging noises followed by a dog barking<|endoftext|>
# ['mbring violin feedback.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bell rings and a synthesized object is played<|endoftext|>
# ['Paper Cup Hollow Slide Scissor Snips.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person breathes heavily and something is repeatedly and forcefully filed<|endoftext|>
# ['Ambience Coffee Shop 4 .wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A crowd of people talking<|endoftext|>
# ['RED LINE.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A machine works while a woman talks far away<|endoftext|>
# ['parking2.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle engine idling and people talking<|endoftext|>
# ['109473__jovica__layers-020-n-dimensional-space-62_2.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A muffled vehicle engine accelerating as wind blows into a microphone<|endoftext|>
# ['Maritiem Museum Mainport 07 090511.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A woman speaking in the background as a group of people talk in the distance<|endoftext|>
# ['18 Little Group.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A humming and music<|endoftext|>
# ['20100327.seafront.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves and a man talks<|endoftext|>
# ['ambient__DEEP.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves slowly<|endoftext|>
# ['Shaking pills in plastic container.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and crumpling paper<|endoftext|>
# ['Stream_00198.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water rushes down a stream<|endoftext|>
# ['TRAIN_MSSG.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A man speaks over a loudspeaker as a small motor revs up<|endoftext|>
# ['Food Sizzling.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls and something is fried<|endoftext|>
# ['Urban Ambience(birds, wind, leaves, cars)_1-2.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle engine is running and birds are chirping<|endoftext|>
# ['metal on metal.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and scraping of wood<|endoftext|>
# ['macbook fan noise.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A small motor is running and accelerates<|endoftext|>
# ['Horses.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A helicopter flies overhead<|endoftext|>
# ['Ocean 1.0 9-11-16.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows strongly nearby<|endoftext|>
# ['Cuckoo bird.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves while people talk<|endoftext|>
# ['car_1.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle is speeding by<|endoftext|>
# ['Popcorn pop.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and splashing water<|endoftext|>
# ['am statics 1040 to 1220.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat engine running steadily<|endoftext|>
# ['Crushing that Thin Layer of Ice.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Crinkling and crumpling paper<|endoftext|>
# ['Bird-one Mockingbird with many songs.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Birds chirping and tweeting<|endoftext|>
# ['rtty 75 bd testslip the quick brown fox and 1 row ry.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A dial tone is going off<|endoftext|>
# ['clinking_tiles_02.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging and rustling<|endoftext|>
# ['Ambience windy street with trees and birds.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A vehicle moves nearby<|endoftext|>
# ['Cockney weather news.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A person talking with a squeaky sound<|endoftext|>
# ['rain-fragment-eq.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|>
# ['wildernessambience.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A boat motor is running and fades, and birds are chirping<|endoftext|>
# ['a gentle breeze, wind 5.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bee buzzes loudly nearby<|endoftext|>
# ['1 person walking on pavement outside.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A horse galloping and a person singing far away<|endoftext|>
# ['ink jet printer.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clicking and rustling with some light humming<|endoftext|>
# ['on a wooden ship at sea 02.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water splashes and birds chirp<|endoftext|>
# ['080904_00_machine_road_under_construction.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorcycle engine idling<|endoftext|>
# ['FaucetMetalSink90.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Water is running and gurgling<|endoftext|>
# ['Whitchurch Silk Mill waterwheel 1.wav'] <|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A steam engine is chugging along<|endoftext|>

# %%
all_predictions
# Out:
# [{'file_name': ['People Working - Inner Courtyard - Church Bells.wav'],
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Music plays nearby as a person sprays on a surface<|endoftext|>'},
#  {'file_name': ['Rainy weather.wav'],
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A large motor vehicle engine is running and vibrating<|endoftext|>'},
#  {'file_name': ['fireworks.wav'],
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Several explosions and fireworks with some whistling and humming<|endoftext|>'},
#  {'file_name': ['TREADMILL_GYM-AMB.wav'],
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A machine is spraying a surface<|endoftext|>'},
#  {'file_name': ['Air door sound.wav'],
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Wind blows and a vehicle approaches<|endoftext|>'},
#  {'file_name': ['Trsat_Afternoon_--.wav'],
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A bus engine hums<|endoftext|>'},
#  {'file_name': ['Cup_spoon_hotwater.wav'],
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Clanging of glass and liquid<|endoftext|>'},
#  {'file_name': ['Rocks Falling No-Reverb Edition 16 Bit.wav'],
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: Rain falls onto a hard surface<|endoftext|>'},
#  {'file_name': ['Outside Ambience.wav'],
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motorboat is speeding along<|endoftext|>'},
#  {'file_name': ['20140530.country.house.night.wav'],
#   'caption': '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A loud beeping sound with people talking<|endoftext|>'}]

# %%
# save predictions as jsonl to output_dir
log_dir = output_dir / "logs"
output_dir.mkdir(parents=True, exist_ok=True)
log_dir.mkdir(parents=True, exist_ok=True)
timestamp = round(time.time())
with open(output_dir / f"{run_name}_{dataset_name}_{dataset_type}_{timestamp}.jsonl", "w") as f:
    for prediction in all_predictions:
        f.write(json.dumps(prediction) + "\n")

# copy generate_config to log_dir
generate_config_dst = log_dir / f"{timestamp}.yaml"
generate_config_dst.write_text(generate_config.read_text())
# Out:
# 335

# %%
tokenizer.decode(prediction[0])
# Out:
# '<|startoftranscript|><|en|><|transcribe|><|notimestamps|>clotho > caption: A motor vehicle engine is running and vibrating, and people are talking in the background<|endoftext|>'

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 if device.type == 'cuda':
#       2     print(torch.cuda.get_device_name(0))
#       3     print('Memory Usage:')
#
# NameError: name 'device' is not defined

# %%
dataloader
